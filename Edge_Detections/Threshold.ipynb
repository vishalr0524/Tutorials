# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('/home/hp/Documents/Daily_Task/Day_2/Assets/sudoku.jpg')

# %%
# Convert to grayscale (if not already)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply fixed threshold
_, thresh_fixed = cv2.threshold(gray, 120, 255, cv2.THRESH_BINARY)

plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.title("Original Grayscale")

plt.subplot(1,2,2)
plt.imshow(thresh_fixed, cmap='gray')
plt.title("Fixed Threshold (T=120)")
plt.show()

# %%
# Adaptive Mean Thresholding
thresh_adapt_mean = cv2.adaptiveThreshold(
    gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11, 2
)

# Adaptive Gaussian Thresholding
thresh_adapt_gauss = cv2.adaptiveThreshold(
    gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2
)

plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.imshow(thresh_adapt_mean, cmap='gray')
plt.title("Adaptive Mean Threshold")

plt.subplot(1,2,2)
plt.imshow(thresh_adapt_gauss, cmap='gray')
plt.title("Adaptive Gaussian Threshold")
plt.show()

# %%
# Compute Otsu's threshold
_, otsu_thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Compute histogram
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.hist(gray.ravel(), 256, [0,256])
plt.axvline(_, color='red', linestyle='--', label=f'Otsu threshold = {_:.0f}')
plt.title("Histogram with Otsu's Threshold")
plt.legend()

plt.subplot(1,2,2)
plt.imshow(otsu_thresh, cmap='gray')
plt.title("Otsu's Thresholded Image")
plt.show()
# Out:
# /tmp/ipykernel_18043/2391772641.py:7: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.hist(gray.ravel(), 256, [0,256])
